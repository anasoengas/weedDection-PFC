# %%
# !pip3 install scikit-video
# Out:
# Collecting scikit-video
#   Downloading scikit_video-1.1.11-py2.py3-none-any.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 14.0 MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from scikit-video) (1.4.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from scikit-video) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from scikit-video) (1.19.5)
# Installing collected packages: scikit-video
# Successfully installed scikit-video-1.1.11

# %%
import numpy as np
import cv2
from skimage.morphology import disk, opening, remove_small_objects, label
import skvideo.io

from google.colab import drive
drive.mount('/content/drive', force_remount=True)


def normalize0_255(X):
	X = (X - X.min()) / (X.max() - X.min())
	return np.array(X * 255, dtype=np.uint8)

def matrixDivision(M, N):
    C = np.divide(M, N, out=np.zeros_like(M), where=N != 0)
    return C

def order_points(pts):
	# initialzie a list of coordinates that will be ordered
	# such that the first entry in the list is the top-left,
	# the second entry is the top-right, the third is the
	# bottom-right, and the fourth is the bottom-left
	rect = np.zeros((4, 2), dtype = "float32")
	# the top-left point will have the smallest sum, whereas
	# the bottom-right point will have the largest sum
	s = pts.sum(axis = 1)
	rect[0] = pts[np.argmin(s)]
	rect[2] = pts[np.argmax(s)]
	# now, compute the difference between the points, the
	# top-right point will have the smallest difference,
	# whereas the bottom-left will have the largest difference
	diff = np.diff(pts, axis = 1)
	rect[1] = pts[np.argmin(diff)]
	rect[3] = pts[np.argmax(diff)]
	# return the ordered coordinates
	return rect

def four_point_transform(image, pts):
	# obtain a consistent order of the points and unpack them
	# individually
	rect = order_points(pts)
	(tl, tr, br, bl) = rect
	# compute the width of the new image, which will be the
	# maximum distance between bottom-right and bottom-left
	# x-coordiates or the top-right and top-left x-coordinates
	widthA = np.sqrt(((br[0] - bl[0]) ** 2) + ((br[1] - bl[1]) ** 2))
	widthB = np.sqrt(((tr[0] - tl[0]) ** 2) + ((tr[1] - tl[1]) ** 2))
	maxWidth = max(int(widthA), int(widthB))
	# compute the height of the new image, which will be the
	# maximum distance between the top-right and bottom-right
	# y-coordinates or the top-left and bottom-left y-coordinates
	heightA = np.sqrt(((tr[0] - br[0]) ** 2) + ((tr[1] - br[1]) ** 2))
	heightB = np.sqrt(((tl[0] - bl[0]) ** 2) + ((tl[1] - bl[1]) ** 2))
	maxHeight = max(int(heightA), int(heightB))
	# now that we have the dimensions of the new image, construct
	# the set of destination points to obtain a "birds eye view",
	# (i.e. top-down view) of the image, again specifying points
	# in the top-left, top-right, bottom-right, and bottom-left
	# order
	dst = np.array([
		[0, 0],
		[maxWidth - 1, 0],
		[maxWidth - 1, maxHeight - 1],
		[0, maxHeight - 1]], dtype = "float32")
	# compute the perspective transform matrix and then apply it
	M = cv2.getPerspectiveTransform(rect, dst)
	warped = cv2.warpPerspective(image, M, (maxWidth, maxHeight))
	# return the warped image
	return warped


def summarizeHorizontal(linhaHorizontal):
  h = np.empty(len(linhaHorizontal), dtype=int)
  idx = 0
  while(idx < len(linhaHorizontal)):
    if linhaHorizontal[idx] == 0:
      h[idx] = 0
      idx = idx + 1
    else:
      i_start = idx
      soma = 0
      while idx < len(linhaHorizontal) and linhaHorizontal[idx]==1:
        soma = soma + linhaHorizontal[idx]
        idx = idx + 1
      i_end = idx
      h[i_start:i_end] = soma
  return h

pvideo = cv2.VideoCapture('/content/drive/My Drive/PFC/MVI_2576.MOV')


kernel = cv2.getStructuringElement(cv2.MORPH_RECT,(3,3))

# Parametro; quantidade de frames para operação AND lógico
historyFrames = 5 # artigo usa 8, antes era 5
listPrevFrames = []
index = 0
contFrames = 0
#writerCulturaErvas = cv2.VideoWriter("/content/drive/My Drive/AnaPaula/dados/CulturaErvas.mkv", cv2.VideoWriter_fourcc(*'X264'), 30.0, (640,360))
#writer = skvideo.io.FFmpegWriter("/content/drive/My Drive/AnaPaula/dados/outputvideo.mp4")


while(pvideo.isOpened()):
    if index%10 ==0:
      print("Processando frame = ", index)
    ret, frame = pvideo.read()
    frame_lido = np.copy(frame)

    if not ret or index >= 5800:
      print("Fim de processamento. Saindo ...")
      break
    if index <= 1300:
      index = index + 1
      continue
    #frame = cv2.resize(frame,None,fx=0.5,fy=0.5)
    
    frame = frame[280:640,640:1280,:] # 360 x 640
    frame_lido = cv2.rectangle(frame_lido,(640, 280),(1280, 640),(0,0,255),3)

    frame_recortado = np.copy(frame)
    pts = np.float32([[240, 0],[440,0],[0,359],[639,359]])
    framePerspectiva = four_point_transform(frame, pts)
    frame = framePerspectiva

    frame_original = np.copy(frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    cultura_erva = np.copy(frame_original)
    FIPSobreposto = np.copy(frame_original)
    FIPRCRCSobreposto = np.copy(frame_original)


    frame = frame/255
    R = frame[:,:,0]
    G = frame[:,:,1]
    B = frame[:,:,2]

    RGB = R + G + B

    r = matrixDivision(R,RGB)
    g = matrixDivision(G,RGB)
    b = matrixDivision(B,RGB)

    CIVE = 0.441*r - 0.881*g + 0.385*b + 18.78745
    CIVE_norm = normalize0_255(CIVE)

    ret2,binOtsu = cv2.threshold(CIVE_norm,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
    binOtsu = (255 - binOtsu)/255 

    if contFrames < historyFrames:
    	listPrevFrames.append(binOtsu)
    else:
    	listPrevFrames.pop(0)
    	listPrevFrames.append(binOtsu)
    contFrames = contFrames + 1
    
    
    
    resAND = np.ones((CIVE_norm.shape[0], CIVE_norm.shape[1]))
    for binImg in listPrevFrames:
    	resAND = np.logical_and(resAND, binImg)
          
    # Fazer operacao de abertur morfológica (opening): verificar tamanho do elemento estruturante ...
    # usado no artigo do Burgos
    #resOpening = cv2.morphologyEx(resAND.astype(np.uint8), cv2.MORPH_OPEN, kernel)
    resOpening = cv2.erode(resAND.astype(np.uint8), kernel)


    # Extracao das linhas de plantio (areas de 	7 a 10 vezes maiores que as manchas de ervas daninhas). 
    # Como estimar isso se não seu o tamanho das áreas de ervas daninhas. Talvez ele explica mais adiante nos resultados
    # Resumindo: Remover regioes menores que um dado limiar
    resOpening_bool = np.array(resOpening, bool) 
    resOpening_cleaned = remove_small_objects(resOpening_bool, min_size=500)
    resOpening_bool = np.array(resOpening, bool) 
    RCRD = np.array(resOpening_cleaned, dtype='int')

    #FIM##############################################################################################


    # Fast Image Processing (FIP) de Baixa Granuralidade
    #INICIO##########################################################################################
    lenFatia = 6 # o artigo usa 16. Antes era 8 #[4, 8, 12, 16]
    thrFatia = 4 #round(0.8*lenFatia) # o artigo usa 12 (que é 3/4 de 16). Antes era 5 # 
    thrLargura = 3.0
    #ajuste_thrLargura = 0.1

    [nLines, nColumns] = binOtsu.shape
    nFatias = int(nLines/lenFatia)
    PROJImage = np.zeros((nLines, nColumns))
    FIPImage = np.zeros((nLines, nColumns))
    cultureImage = np.zeros((nLines, nColumns))
    ervasDaninhas = np.zeros((nLines, nColumns))
    for i in range(nFatias)[::-1]: # de nFatias - 1 até zero
    	p = np.sum(binOtsu[i*lenFatia:i*lenFatia+lenFatia],axis=0) #soma ao longo de fatia
    	p = p>=thrFatia # filtra a projecao
        
    	# escreve a projecao vertical numa imagem preta e branco  
    	PROJImage[i*lenFatia:i*lenFatia+lenFatia] = np.array(p, dtype='int')
       
      # Fazer filtro com limiar de 5% da largura da imagem (linha), na fatia de baixo. Diminuar o limiar em 2.5% ao longo de cada fatia acima, isto é ...  
    	h = summarizeHorizontal(np.array(p, dtype='int'))
       
        
    	#thrLargura = thrLargura+ thrLargura*ajuste_thrLargura
    	FIPImage[i*lenFatia:i*lenFatia+lenFatia] = np.array((h > thrLargura), dtype='int')
    FIPSobreposto[np.array(FIPImage, dtype='bool')] = [0, 255, 0] #[blue, green, red]

    FIPRCRCSobreposto[np.array(FIPImage, dtype='bool')] = [0, 255, 0]
    FIPRCRCSobreposto[resOpening_cleaned] = [0, 0, 255]



    # Fast Image Processing (FIP) de Alta Granuralidade
    #INICIO##########################################################################################
    lenFatia = 86 # o artigo usa 16. Antes era 8
    thrFatia = 54 #round(0.8*lenFatia) # o artigo usa 12 (que é 3/4 de 16). Antes era 5
    thrLargura = 3.0
    #ajuste_thrLargura = 0.1

    [nLines, nColumns] = binOtsu.shape
    nFatias = int(nLines/lenFatia)
    PROJImage_ALTA = np.zeros((nLines, nColumns))
    FIPImage_ALTA = np.zeros((nLines, nColumns))
    ervasDaninhas_COLADAS = np.zeros((nLines, nColumns))
    for i in range(nFatias)[::-1]: # de nFatias - 1 até zero
    	p = np.sum(binOtsu[i*lenFatia:i*lenFatia+lenFatia],axis=0) #soma ao longo de fatia
    	p = p>=thrFatia # filtra a projecao
        
    	# escreve a projecao vertical numa imagem preta e branco  
    	PROJImage_ALTA[i*lenFatia:i*lenFatia+lenFatia] = np.array(p, dtype='int')
       
      # Fazer filtro com limiar de 5% da largura da imagem (linha), na fatia de baixo. Diminuar o limiar em 2.5% ao longo de cada fatia acima, isto é ...  
    	h = summarizeHorizontal(np.array(p, dtype='int'))
       
        
    	#thrLargura = thrLargura+ thrLargura*ajuste_thrLargura
    	FIPImage_ALTA[i*lenFatia:i*lenFatia+lenFatia] = np.array((h > thrLargura), dtype='int')
     	

    #FIM##########################################################################################

    # JUNCAO DE RCRD COM FIP

    # VEGETACAO = regiões de FIP que tem interseção com a imagem RCRD
    # ideia: rotular as regiões de FIP. Para cada regiões de FIP verificar se a intersecção com RCRD é não vazia
    labeledFIP =   label(binOtsu, connectivity=2) # connectivity=2 eh o mesmo que 8-conectados
    for lab in range(1, labeledFIP.max()+1):
    	regiaoSel = labeledFIP==lab
    	resIntesection = np.logical_and(regiaoSel, resOpening_cleaned)
    	if not np.all(resIntesection == False):
    	  cultura_erva[regiaoSel] = [0, 255, 0] # desenha na imagem original
    	  cultureImage[regiaoSel] = 1

    # ERVAS DANINHAS = todos os pixels de vegetacao que nao sao cultura (linha de plantion)
    ervasDaninhas = binOtsu - cultureImage # cultureImage eh linha de plantio 
    

    # Calcula ervas daninhas coladas
    ervasDaninhas_COLADAS = np.array(binOtsu,int) - np.array(FIPImage_ALTA, dtype='int')
    ervasDaninhas_COLADAS1 = ervasDaninhas_COLADAS > 0
    ervasDaninhas_COLADAS2 = remove_small_objects(ervasDaninhas_COLADAS1, min_size=800)

    ervasDaninhasCOPY = np.copy(ervasDaninhas)

    ervasDaninhas = np.logical_or(ervasDaninhas, ervasDaninhas_COLADAS2)

    # EXCLUE ERVAS DANINHAS NAS MARGENS ESQUERDA E DIREITA
    [N,M] = ervasDaninhas.shape
    #print(N, M)
    coords = np.argwhere(ervasDaninhas == True)
    for coord in coords:
      if coord[1]<=100 or abs(coord[1]-M)<=100 or abs(coord[0]-N)<=50:
        ervasDaninhas[coord[0], coord[1]] = False

    cultura_erva[np.array(ervasDaninhas, bool)] = [0, 0, 255]

    linhasCompleta = cultureImage - ervasDaninhas


    #Assim que processar cada frame
    #writerCulturaErvas.write(cultura_erva)
    #writer.writeFrame(cv2.cvtColor(cultura_erva, cv2.COLOR_BGR2RGB))


    if index%25 == 0:
      #cv2.imwrite('/content/drive/My Drive/AnaPaula/dados/saidav2/frame'+str(index)+'.png',frame_original)
      cv2.imwrite('/content/drive/My Drive/PFC/saidav3/frame'+str(index)+'LIDO.png',frame_lido)
      cv2.imwrite('/content/drive/My Drive/PFC/saidav3/frame'+str(index)+'FIP_ALTA.png',FIPImage_ALTA*255)
      cv2.imwrite('/content/drive/My Drive/PFC/saidav3/frame'+str(index)+'ERVASBURGOS.png',ervasDaninhasCOPY*255)
      cv2.imwrite('/content/drive/My Drive/PFC/saidav3/frame'+str(index)+'RESIDUO.png',ervasDaninhas_COLADAS1*255)
      cv2.imwrite('/content/drive/My Drive/PFC/saidav3/frame'+str(index)+'ERVAS_COLADAS.png',ervasDaninhas_COLADAS2*255)
      cv2.imwrite('/content/drive/My Drive/PFC/saidav3/frame'+str(index)+'RECORTADO.png',frame_recortado) 
      cv2.imwrite('/content/drive/My Drive/PFC/saidav3/frame'+str(index)+'Perspectiva.png',framePerspectiva)
      cv2.imwrite('/content/drive/My Drive/PFC/saidav3/frame'+str(index)+'CIVE.png',CIVE_norm)
      cv2.imwrite('/content/drive/My Drive/PFC/saidav3/frame'+str(index)+'OTSU.png',binOtsu*255)
      cv2.imwrite('/content/drive/My Drive/PFC/saidav3/frame'+str(index)+'AND.png',resAND*255)
      cv2.imwrite('/content/drive/My Drive/PFC/saidav3/frame'+str(index)+'PROJVertical.png',PROJImage*255)
      cv2.imwrite('/content/drive/My Drive/PFC/saidav3/frame'+str(index)+'FIP.png',FIPImage*255)
      cv2.imwrite('/content/drive/My Drive/PFC/saidav3/frame'+str(index)+'FIPSobreposto.png',FIPSobreposto)
      cv2.imwrite('/content/drive/My Drive/PFC/saidav3/frame'+str(index)+'FIPRCRDSobreposto.png',FIPRCRCSobreposto)
      cv2.imwrite('/content/drive/My Drive/PFC/saidav3/frame'+str(index)+'Opening.png',resOpening*255)
      cv2.imwrite('/content/drive/My Drive/PFC/saidav3/frame'+str(index)+'Opening_Cleaned[RCRD].png',RCRD*255)
      cv2.imwrite('/content/drive/My Drive/PFC/saidav3/frame'+str(index)+'CulturaErvas.png',cultura_erva)
      cv2.imwrite('/content/drive/My Drive/PFC/saidav3/frame'+str(index)+'ErvasDaninhas.png',ervasDaninhas*255)
      cv2.imwrite('/content/drive/My Drive/PFC/saidav3/frame'+str(index)+'LinhasCultura.png',cultureImage*255)
      cv2.imwrite('/content/drive/My Drive/PFC/saidav3/frame'+str(index)+'LinhasCulturaCompletas.png',linhasCompleta*255)
    index = index + 1

pvideo.release()
#writerCulturaErvas.release()
#writer.close()
#cv2.destroyAllWindows()
# Out:
# Mounted at /content/drive
# Processando frame =  0
# Processando frame =  10
# Processando frame =  20
# Processando frame =  30
# Processando frame =  40
# Processando frame =  50
# Processando frame =  60
# Processando frame =  70
# Processando frame =  80
# Processando frame =  90
# Processando frame =  100
# Processando frame =  110
# Processando frame =  120
# Processando frame =  130
# Processando frame =  140
# Processando frame =  150
# Processando frame =  160
# Processando frame =  170
# Processando frame =  180
# Processando frame =  190
# Processando frame =  200
# Processando frame =  210
# Processando frame =  220
# Processando frame =  230
# Processando frame =  240
# Processando frame =  250
# Processando frame =  260
# Processando frame =  270
# Processando frame =  280
# Processando frame =  290
# Processando frame =  300
# Processando frame =  310
# Processando frame =  320
# Processando frame =  330
# Processando frame =  340
# Processando frame =  350
# Processando frame =  360
# Processando frame =  370
# Processando frame =  380
# Processando frame =  390
# Processando frame =  400
# Processando frame =  410
# Processando frame =  420
# Processando frame =  430
# Processando frame =  440
# Processando frame =  450
# Processando frame =  460
# Processando frame =  470
# Processando frame =  480
# Processando frame =  490
# Processando frame =  500
# Processando frame =  510
# Processando frame =  520
# Processando frame =  530
# Processando frame =  540
# Processando frame =  550
# Processando frame =  560
# Processando frame =  570
# Processando frame =  580
# Processando frame =  590
# Processando frame =  600
# Processando frame =  610
# Processando frame =  620
# Processando frame =  630
# Processando frame =  640
# Processando frame =  650
# Processando frame =  660
# Processando frame =  670
# Processando frame =  680
# Processando frame =  690
# Processando frame =  700
# Processando frame =  710
# Processando frame =  720
# Processando frame =  730
# Processando frame =  740
# Processando frame =  750
# Processando frame =  760
# Processando frame =  770
# Processando frame =  780
# Processando frame =  790
# Processando frame =  800
# Processando frame =  810
# Processando frame =  820
# Processando frame =  830
# Processando frame =  840
# Processando frame =  850
# Processando frame =  860
# Processando frame =  870
# Processando frame =  880
# Processando frame =  890
# Processando frame =  900
# Processando frame =  910
# Processando frame =  920
# Processando frame =  930
# Processando frame =  940
# Processando frame =  950
# Processando frame =  960
# Processando frame =  970
# Processando frame =  980
# Processando frame =  990
# Processando frame =  1000
# Processando frame =  1010
# Processando frame =  1020
# Processando frame =  1030
# Processando frame =  1040
# Processando frame =  1050
# Processando frame =  1060
# Processando frame =  1070
# Processando frame =  1080
# Processando frame =  1090
# Processando frame =  1100
# Processando frame =  1110
# Processando frame =  1120
# Processando frame =  1130
# Processando frame =  1140
# Processando frame =  1150
# Processando frame =  1160
# Processando frame =  1170
# Processando frame =  1180
# Processando frame =  1190
# Processando frame =  1200
# Processando frame =  1210
# Processando frame =  1220
# Processando frame =  1230
# Processando frame =  1240
# Processando frame =  1250
# Processando frame =  1260
# Processando frame =  1270
# Processando frame =  1280
# Processando frame =  1290
# Processando frame =  1300
# Processando frame =  1310
# Processando frame =  1320
# Processando frame =  1330
# Processando frame =  1340
# Processando frame =  1350
# Processando frame =  1360
# Processando frame =  1370
# Processando frame =  1380
# Processando frame =  1390
# Processando frame =  1400
# Processando frame =  1410
# Processando frame =  1420
# Processando frame =  1430
# Processando frame =  1440
# Processando frame =  1450
# Processando frame =  1460
# Processando frame =  1470
# Processando frame =  1480
# Processando frame =  1490
# Processando frame =  1500
# Processando frame =  1510
# Processando frame =  1520
# Processando frame =  1530
# Processando frame =  1540
# Processando frame =  1550
# Processando frame =  1560
# Processando frame =  1570
# Processando frame =  1580
# Processando frame =  1590
# Processando frame =  1600
# Processando frame =  1610
# Processando frame =  1620
# Processando frame =  1630
# Processando frame =  1640
# Processando frame =  1650
# Processando frame =  1660
# Processando frame =  1670
# Processando frame =  1680
# Processando frame =  1690
# Processando frame =  1700
# Processando frame =  1710
# Processando frame =  1720
# Processando frame =  1730
# Processando frame =  1740
# Processando frame =  1750
# Processando frame =  1760
# Processando frame =  1770
# Processando frame =  1780
# Processando frame =  1790
# Processando frame =  1800
# Processando frame =  1810
# Processando frame =  1820
# Processando frame =  1830
# Processando frame =  1840
# Processando frame =  1850
# Processando frame =  1860
# Processando frame =  1870
# Processando frame =  1880
# Processando frame =  1890
# Processando frame =  1900
# Processando frame =  1910
# Processando frame =  1920
# Processando frame =  1930
# Processando frame =  1940
# Processando frame =  1950
# Processando frame =  1960
# Processando frame =  1970
# Processando frame =  1980
# Processando frame =  1990
# Processando frame =  2000
# Processando frame =  2010
# Processando frame =  2020
# Processando frame =  2030
# Processando frame =  2040
# Processando frame =  2050
# Processando frame =  2060
# Processando frame =  2070
# Processando frame =  2080
# Processando frame =  2090
# Processando frame =  2100
# Processando frame =  2110
# Processando frame =  2120
# Processando frame =  2130
# Processando frame =  2140
# Processando frame =  2150
# Processando frame =  2160
# Processando frame =  2170
# Processando frame =  2180
# Processando frame =  2190
# Processando frame =  2200
# Processando frame =  2210
# Processando frame =  2220
# Processando frame =  2230
# Processando frame =  2240
# Processando frame =  2250
# Processando frame =  2260
# Processando frame =  2270
# Processando frame =  2280
# Processando frame =  2290
# Processando frame =  2300
# Processando frame =  2310
# Processando frame =  2320
# Processando frame =  2330
# Processando frame =  2340
# Processando frame =  2350
# Processando frame =  2360
# Processando frame =  2370
# Processando frame =  2380
# Processando frame =  2390
# Processando frame =  2400
# Processando frame =  2410
# Processando frame =  2420
# Processando frame =  2430
# Processando frame =  2440
# Processando frame =  2450
# Processando frame =  2460
# Processando frame =  2470
# Processando frame =  2480
# Processando frame =  2490
# Processando frame =  2500
# Processando frame =  2510
# Processando frame =  2520
# Processando frame =  2530
# Processando frame =  2540
# Processando frame =  2550
# Processando frame =  2560
# Processando frame =  2570
# Processando frame =  2580
# Processando frame =  2590
# Processando frame =  2600
# Processando frame =  2610
# Processando frame =  2620
# Processando frame =  2630
# Processando frame =  2640
# Processando frame =  2650
# Processando frame =  2660
# Processando frame =  2670
# Processando frame =  2680
# Processando frame =  2690
# Processando frame =  2700
# Processando frame =  2710
# Processando frame =  2720
# Processando frame =  2730
# Processando frame =  2740
# Processando frame =  2750
# Processando frame =  2760
# Processando frame =  2770
# Processando frame =  2780
# Processando frame =  2790
# Processando frame =  2800
# Processando frame =  2810
# Processando frame =  2820
# Processando frame =  2830
# Processando frame =  2840
# Processando frame =  2850
# Processando frame =  2860
# Processando frame =  2870
# Processando frame =  2880
# Processando frame =  2890
# Processando frame =  2900
# Processando frame =  2910
# Processando frame =  2920
# Processando frame =  2930
# Processando frame =  2940
# Processando frame =  2950
# Processando frame =  2960
# Processando frame =  2970
# Processando frame =  2980
# Processando frame =  2990
# Processando frame =  3000
# Processando frame =  3010
# Processando frame =  3020
# Processando frame =  3030
# Processando frame =  3040
# Processando frame =  3050
# Processando frame =  3060
# Processando frame =  3070
# Processando frame =  3080
# Processando frame =  3090
# Processando frame =  3100
# Processando frame =  3110
# Processando frame =  3120
# Processando frame =  3130
# Processando frame =  3140
# Processando frame =  3150
# Processando frame =  3160
# Processando frame =  3170
# Processando frame =  3180
# Processando frame =  3190
# Processando frame =  3200
# Processando frame =  3210
# Processando frame =  3220
# Processando frame =  3230
# Processando frame =  3240
# Processando frame =  3250
# Processando frame =  3260
# Processando frame =  3270
# Processando frame =  3280
# Processando frame =  3290
# Processando frame =  3300
# Processando frame =  3310
# Processando frame =  3320
# Processando frame =  3330
# Processando frame =  3340
# Processando frame =  3350
# Processando frame =  3360
# Processando frame =  3370
# Processando frame =  3380
# Processando frame =  3390
# Processando frame =  3400
# Processando frame =  3410
# Processando frame =  3420
# Processando frame =  3430
# Processando frame =  3440
# Processando frame =  3450
# Processando frame =  3460
# Processando frame =  3470
# Processando frame =  3480
# Processando frame =  3490
# Processando frame =  3500
# Processando frame =  3510
# Processando frame =  3520
# Processando frame =  3530
# Processando frame =  3540
# Processando frame =  3550
# Processando frame =  3560
# Processando frame =  3570
# Processando frame =  3580
# Processando frame =  3590
# Processando frame =  3600
# Processando frame =  3610
# Processando frame =  3620
# Processando frame =  3630
# Processando frame =  3640
# Processando frame =  3650
# Processando frame =  3660
# Processando frame =  3670
# Processando frame =  3680
# Processando frame =  3690
# Processando frame =  3700
# Processando frame =  3710
# Processando frame =  3720
# Processando frame =  3730
# Processando frame =  3740
# Processando frame =  3750
# Processando frame =  3760
# Processando frame =  3770
# Processando frame =  3780
# Processando frame =  3790
# Processando frame =  3800
# Processando frame =  3810
# Processando frame =  3820
# Processando frame =  3830
# Processando frame =  3840
# Processando frame =  3850
# Processando frame =  3860
# Processando frame =  3870
# Processando frame =  3880
# Processando frame =  3890
# Processando frame =  3900
# Processando frame =  3910
# Processando frame =  3920
# Processando frame =  3930
# Processando frame =  3940
# Processando frame =  3950
# Processando frame =  3960
# Processando frame =  3970
# Processando frame =  3980
# Processando frame =  3990
# Processando frame =  4000
# Processando frame =  4010
# Processando frame =  4020
# Processando frame =  4030
# Processando frame =  4040
# Processando frame =  4050
# Processando frame =  4060
# Processando frame =  4070
# Processando frame =  4080
# Processando frame =  4090
# Processando frame =  4100
# Processando frame =  4110
# Processando frame =  4120
# Processando frame =  4130
# Processando frame =  4140
# Processando frame =  4150
# Processando frame =  4160
# Processando frame =  4170
# Processando frame =  4180
# Processando frame =  4190
# Processando frame =  4200
# Processando frame =  4210
# Processando frame =  4220
# Processando frame =  4230
# Processando frame =  4240
# Processando frame =  4250
# Processando frame =  4260
# Processando frame =  4270
# Processando frame =  4280
# Processando frame =  4290
# Processando frame =  4300
# Processando frame =  4310
# Processando frame =  4320
# Processando frame =  4330
# Processando frame =  4340
# Processando frame =  4350
# Processando frame =  4360
# Processando frame =  4370
# Processando frame =  4380
# Processando frame =  4390
# Processando frame =  4400
# Processando frame =  4410
# Processando frame =  4420
# Processando frame =  4430
# Processando frame =  4440
# Processando frame =  4450
# Processando frame =  4460
# Processando frame =  4470
# Processando frame =  4480
# Processando frame =  4490
# Processando frame =  4500
# Processando frame =  4510
# Processando frame =  4520
# Processando frame =  4530
# Processando frame =  4540
# Processando frame =  4550
# Processando frame =  4560
# Processando frame =  4570
# Processando frame =  4580
# Processando frame =  4590
# Processando frame =  4600
# Processando frame =  4610
# Processando frame =  4620
# Processando frame =  4630
# Processando frame =  4640
# Processando frame =  4650
# Processando frame =  4660
# Processando frame =  4670
# Processando frame =  4680
# Processando frame =  4690
# Processando frame =  4700
# Processando frame =  4710
# Processando frame =  4720
# Processando frame =  4730
# Processando frame =  4740
# Processando frame =  4750
# Processando frame =  4760
# Processando frame =  4770
# Processando frame =  4780
# Processando frame =  4790
# Processando frame =  4800
# Processando frame =  4810
# Processando frame =  4820
# Processando frame =  4830
# Processando frame =  4840
# Processando frame =  4850
# Processando frame =  4860
# Processando frame =  4870
# Processando frame =  4880
# Processando frame =  4890
# Processando frame =  4900
# Processando frame =  4910
# Processando frame =  4920
# Processando frame =  4930
# Processando frame =  4940
# Processando frame =  4950
# Processando frame =  4960
# Processando frame =  4970
# Processando frame =  4980
# Processando frame =  4990
# Processando frame =  5000
# Processando frame =  5010
# Processando frame =  5020
# Processando frame =  5030
# Processando frame =  5040
# Processando frame =  5050
# Processando frame =  5060
# Processando frame =  5070
# Processando frame =  5080
# Processando frame =  5090
# Processando frame =  5100
# Processando frame =  5110
# Processando frame =  5120
# Processando frame =  5130
# Processando frame =  5140
# Processando frame =  5150
# Processando frame =  5160
# Processando frame =  5170
# Processando frame =  5180
# Processando frame =  5190
# Processando frame =  5200
# Processando frame =  5210
# Processando frame =  5220
# Processando frame =  5230
# Processando frame =  5240
# Processando frame =  5250
# Processando frame =  5260
# Processando frame =  5270
# Processando frame =  5280
# Processando frame =  5290
# Processando frame =  5300
# Processando frame =  5310
# Processando frame =  5320
# Processando frame =  5330
# Processando frame =  5340
# Processando frame =  5350
# Processando frame =  5360
# Processando frame =  5370
# Processando frame =  5380
# Processando frame =  5390
# Processando frame =  5400
# Processando frame =  5410
# Processando frame =  5420
# Processando frame =  5430
# Processando frame =  5440
# Processando frame =  5450
# Processando frame =  5460
# Processando frame =  5470
# Processando frame =  5480
# Processando frame =  5490
# Processando frame =  5500
# Processando frame =  5510
# Processando frame =  5520
# Processando frame =  5530
# Processando frame =  5540
# Processando frame =  5550
# Processando frame =  5560
# Processando frame =  5570
# Processando frame =  5580
# Processando frame =  5590
# Processando frame =  5600
# Processando frame =  5610
# Processando frame =  5620
# Processando frame =  5630
# Processando frame =  5640
# Processando frame =  5650
# Processando frame =  5660
# Processando frame =  5670
# Processando frame =  5680
# Processando frame =  5690
# Processando frame =  5700
# Processando frame =  5710
# Processando frame =  5720
# Processando frame =  5730
# Processando frame =  5740
# Processando frame =  5750
# Processando frame =  5760
# Processando frame =  5770
# Processando frame =  5780
# Processando frame =  5790
# Processando frame =  5800
# Fim de processamento. Saindo ...
